# %%
# !pip install umap-learn
# Out:
# Requirement already satisfied: umap-learn in c:\users\egor\pycharmprojects\dl-assignment-4-gcnn\venv\lib\site-packages (0.5.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\egor\pycharmprojects\dl-assignment-4-gcnn\venv\lib\site-packages (from umap-learn) (1.21.6)
# Requirement already satisfied: numba>=0.49 in c:\users\egor\pycharmprojects\dl-assignment-4-gcnn\venv\lib\site-packages (from umap-learn) (0.55.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\egor\pycharmprojects\dl-assignment-4-gcnn\venv\lib\site-packages (from umap-learn) (1.8.0)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\egor\pycharmprojects\dl-assignment-4-gcnn\venv\lib\site-packages (from umap-learn) (0.5.6)
# Requirement already satisfied: tqdm in c:\users\egor\pycharmprojects\dl-assignment-4-gcnn\venv\lib\site-packages (from umap-learn) (4.64.0)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\egor\pycharmprojects\dl-assignment-4-gcnn\venv\lib\site-packages (from umap-learn) (1.0.2)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\egor\pycharmprojects\dl-assignment-4-gcnn\venv\lib\site-packages (from numba>=0.49->umap-learn) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\egor\pycharmprojects\dl-assignment-4-gcnn\venv\lib\site-packages (from numba>=0.49->umap-learn) (57.0.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\egor\pycharmprojects\dl-assignment-4-gcnn\venv\lib\site-packages (from pynndescent>=0.5->umap-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\egor\pycharmprojects\dl-assignment-4-gcnn\venv\lib\site-packages (from scikit-learn>=0.22->umap-learn) (3.1.0)
# Requirement already satisfied: colorama in c:\users\egor\pycharmprojects\dl-assignment-4-gcnn\venv\lib\site-packages (from tqdm->umap-learn) (0.4.4)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import umap
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style='white', context='poster')

# %%
data = pd.read_csv("../data/Train_call.txt", sep='\t')
y = pd.read_csv("../data/Train_clinical.txt", sep='\t')

data.drop(['Chromosome','Start','End','Nclone'], axis=1, inplace=True)
y.drop(['Sample'], axis=1, inplace=True)

classes = np.squeeze(y).astype('category').cat.categories

# %% [markdown]
# Supervised UMAP

# %%
x_train, x_test, y_train, y_test = \
    train_test_split(data.T, np.squeeze(y).astype('category').cat.codes,
                     test_size = 0.3, random_state=4)

# %%
mapper = umap.UMAP(n_neighbors=10, metric='correlation').fit(x_train, y=y_train)

# %%
fig, ax = plt.subplots(1, figsize=(14, 10))
plt.scatter(*mapper.embedding_.T, c=y_train, cmap='viridis', alpha=1.0)
plt.setp(ax, xticks=[], yticks=[])
cbar = plt.colorbar(boundaries=np.arange(4)-0.5)
cbar.set_ticks(np.arange(3))
cbar.set_ticklabels(classes)
plt.title('Train Dataset Embedded via UMAP using Labels');

# %%
test_embedding = mapper.transform(x_test)

# %%
fig, ax = plt.subplots(1, figsize=(14, 10))
plt.scatter(*test_embedding.T, c=np.array(y_test), cmap='viridis', alpha=1.0)
plt.setp(ax, xticks=[], yticks=[])
cbar = plt.colorbar(boundaries=np.arange(4)-0.5)
cbar.set_ticks(np.arange(3))
cbar.set_ticklabels(classes)
plt.title('Test Dataset Embedded via UMAP');

# %% [markdown]
# Unsupervised UMAP

# %%
mapper_full = umap.UMAP(metric='braycurtis').fit(data.T)

# %%
fig, ax = plt.subplots(1, figsize=(14, 10))
plt.scatter(*mapper_full.embedding_.T,
            c=np.squeeze(y).astype('category').cat.codes, cmap='viridis', alpha=1.0)
plt.setp(ax, xticks=[], yticks=[])
cbar = plt.colorbar(boundaries=np.arange(4)-0.5)
cbar.set_ticks(np.arange(3))
cbar.set_ticklabels(classes)
plt.title('Test Dataset Embedded via UMAP');

# %% [markdown]
# Semisupervised UMAP

# %%
y_masked = np.squeeze(y).astype('category').cat.codes.copy()
y_masked[y_test.index]=-1

# %%
fitter = umap.UMAP(metric='canberra').fit(data.T, y=y_masked)
embedding = fitter.embedding_

# %%
fig, ax = plt.subplots(1, figsize=(14, 10))
plt.scatter(*embedding.T[:,y_test.index],
            c=np.squeeze(y).astype('category').cat.codes[y_test.index], cmap='viridis', alpha=1.0)
plt.setp(ax, xticks=[], yticks=[])
cbar = plt.colorbar(boundaries=np.arange(4)-0.5)
cbar.set_ticks(np.arange(3))
cbar.set_ticklabels(classes)
plt.title('Test Dataset Embedded via UMAP using Partial Labels');

# %%
fig, ax = plt.subplots(1, figsize=(14, 10))
plt.scatter(*embedding.T[:,y_train.index],
            c=np.squeeze(y).astype('category').cat.codes[y_train.index], cmap='viridis', alpha=1.0)
plt.setp(ax, xticks=[], yticks=[])
cbar = plt.colorbar(boundaries=np.arange(4)-0.5)
cbar.set_ticks(np.arange(3))
cbar.set_ticklabels(classes)
plt.title('Train Dataset Embedded via UMAP using Partial Labels');

# %%
fig, ax = plt.subplots(1, figsize=(14, 10))
plt.scatter(*embedding.T,
            c=np.squeeze(y).astype('category').cat.codes, cmap='viridis', alpha=1.0)
plt.setp(ax, xticks=[], yticks=[])
cbar = plt.colorbar(boundaries=np.arange(4)-0.5)
cbar.set_ticks(np.arange(3))
cbar.set_ticklabels(classes)
plt.title('Full Dataset Embedded via UMAP using Partial Labels');
